# %%
import numpy as np
import pandas as pd
import seaborn as sn
import sklearn as sk
from sklearn.feature_extraction.text import CountVectorizer
import tpot as tp
import contractions
import spacy
import tensorflow as tf
import keras as k
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# Using TensorFlow backend.

# %%
conda env export > environment.yaml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
wines = pd.read_csv('wines.csv')

wines.head()
# Out:
#   country                                        description  points  price  \
# 0      US  tremendous varietal wine hail oakville age thr...      96    235
# 1   Spain  ripe aroma fig blackberry cassis soften sweete...      96    110
# 2      US  mac watson honor memory wine make mother treme...      96     90
# 3      US  spend month new french oak incorporate fruit p...      96     65
# 4  France  top wine la begude name high point vineyard fo...      95     66
#
#          province             variety                   winery
# 0      California  Cabernet Sauvignon                    heitz
# 1  Northern Spain       Tinta de Toro  bodega carmen rodriguez
# 2      California     Sauvignon Blanc                 macauley
# 3          Oregon          Pinot Noir                    ponzi
# 4        Provence  Provence red blend     domaine de la begude

# %%
wines.description.head()
# Out:
# 0    tremendous varietal wine hail oakville age thr...
# 1    ripe aroma fig blackberry cassis soften sweete...
# 2    mac watson honor memory wine make mother treme...
# 3    spend month new french oak incorporate fruit p...
# 4    top wine la begude name high point vineyard fo...
# Name: description, dtype: object

# %%
corpus = wines['description']
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names()
# Out:
# ['aa',
#  'aah',
#  'aalto',
#  'aand',
#  'aaron',
#  'abacela',
#  'abacelas',
#  'abadal',
#  'abadia',
#  'abandon',
#  'abarbanel',
#  'abbacchio',
#  'abbaye',
#  'abbey',
#  'abbinare',
#  'abboccato',
#  'abbona',
#  'abbott',
#  'abbotts',
#  'abbreviate',
#  'abbuoto',
#  'abc',
#  'abeille',
#  'abeilles',
#  'abeja',
#  'abejas',
#  'abelis',
#  'abernathy',
#  'aberrant',
#  'abetina',
#  'abeyance',
#  'abide',
#  'ability',
#  'able',
#  'ably',
#  'abnormal',
#  'abnormally',
#  'aboard',
#  'abondante',
#  'abound',
#  'aboundchalk',
#  'abouriou',
#  'abracadabra',
#  'abrasive',
#  'abrasiveness',
#  'abraxas',
#  'abreu',
#  'abreus',
#  'abrigo',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abruzzi',
#  'abruzzo',
#  'absence',
#  'absense',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbingly',
#  'abstberg',
#  'absurd',
#  'absurdly',
#  'abtsberg',
#  'abundance',
#  'abundanceall',
#  'abundancecitrus',
#  'abundant',
#  'abundantly',
#  'abupt',
#  'abuse',
#  'abut',
#  'abv',
#  'abyss',
#  'ac',
#  'acacia',
#  'acaciaalongside',
#  'acaciaand',
#  'acacias',
#  'academic',
#  'acai',
#  'acccessible',
#  'accelerate',
#  'accelerator',
#  'accent',
#  'accented',
#  'accentfill',
#  'accenting',
#  'accents',
#  'accentsand',
#  'accentsblackberry',
#  'accentsbut',
#  'accentslike',
#  'accentsperhap',
#  'accentsthere',
#  'accentsvanilla',
#  'accentuate',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'access',
#  'accessibile',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accessorize',
#  'acciaiolo',
#  'accident',
#  'accidentthe',
#  'acciderba',
#  'acclaim',
#  'acclaimed',
#  'accolade',
#  'accommodate',
#  'accompanie',
#  'accompaniment',
#  'accompany',
#  'accompanying',
#  'accompinament',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishmentbright',
#  'accomplishmentsometime',
#  'accompnaie',
#  'accord',
#  'accordance',
#  'accordingly',
#  'accordini',
#  'accordion',
#  'account',
#  'accounting',
#  'accpetable',
#  'accrue',
#  'accumulate',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accuse',
#  'accustom',
#  'accustomed',
#  'acdity',
#  'ace',
#  'aceri',
#  'acetate',
#  'acetic',
#  'acetone',
#  'achaval',
#  'achavals',
#  'ache',
#  'achelo',
#  'achieve',
#  'achievement',
#  'achiever',
#  'achingly',
#  'achleiten',
#  'aciar',
#  'acic',
#  'acid',
#  'acida',
#  'acidare',
#  'acidbut',
#  'acidic',
#  'acidically',
#  'acidicpalate',
#  'acidicthe',
#  'acidictoo',
#  'acididty',
#  'acidification',
#  'acidificationjust',
#  'acidified',
#  'acidify',
#  'acidit',
#  'aciditiy',
#  'acidity',
#  'aciditya',
#  'acidityas',
#  'aciditybeautiful',
#  'aciditybut',
#  'aciditygive',
#  'acidityif',
#  'acidityit',
#  'aciditylike',
#  'aciditymake',
#  'aciditypair',
#  'acidityperfect',
#  'aciditysurprising',
#  'aciditythe',
#  'aciditytypical',
#  'acidityvery',
#  'aciditywhich',
#  'aciditywill',
#  'acidsa',
#  'acidty',
#  'acidulated',
#  'acidy',
#  'aciidty',
#  'acinatico',
#  'acknowledge',
#  'acknowledgement',
#  'aconcagua',
#  'acorn',
#  'acorss',
#  'acquaintance',
#  'acquavigna',
#  'acquire',
#  'acquisition',
#  'acquit',
#  'acre',
#  'acreage',
#  'acresthe',
#  'acrid',
#  'acridness',
#  'acrobat',
#  'acrobatic',
#  'across',
#  'acrux',
#  'acrylic',
#  'act',
#  'acter',
#  'action',
#  'active',
#  'actively',
#  'activity',
#  'actor',
#  'actress',
#  'actual',
#  'actuality',
#  'actually',
#  'acustic',
#  'acute',
#  'ad',
#  'adage',
#  'adam',
#  'adamant',
#  'adami',
#  'adamis',
#  'adams',
#  'adapt',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'add',
#  'addamo',
#  'added',
#  'addict',
#  'addicted',
#  'addictive',
#  'addictively',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'ade',
#  'adega',
#  'adelaida',
#  'adelaidas',
#  'adelaide',
#  'adelsheim',
#  'adenzia',
#  'adeo',
#  'adept',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherent',
#  'adhesive',
#  'adi',
#  'adieu',
#  'adige',
#  'adjacent',
#  'adjective',
#  'adjoin',
#  'adjunct',
#  'adjust',
#  'adjustment',
#  'administer',
#  'admirable',
#  'admirably',
#  'admiral',
#  'admiration',
#  'admire',
#  'admired',
#  'admirer',
#  'admission',
#  'admit',
#  'admittedly',
#  'admixture',
#  'adolescent',
#  'adopt',
#  'adorable',
#  'adore',
#  'adorn',
#  'adour',
#  'adquate',
#  'adrianna',
#  'adriano',
#  'adriatic',
#  'adrienne',
#  'adroitly',
#  'adult',
#  'advance',
#  'advanced',
#  'advancedlikely',
#  'advancement',
#  'advantage',
#  'adventure',
#  'adventurous',
#  'adventurously',
#  'adverse',
#  'advertise',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advisable',
#  'advisor',
#  'advocate',
#  'aegerters',
#  'aerate',
#  'aeration',
#  'aerial',
#  'aeroplane',
#  'aesthetic',
#  'affair',
#  'affect',
#  'affected',
#  'affectedwhich',
#  'affection',
#  'afficionado',
#  'affiliated',
#  'affinity',
#  'affirm',
#  'affix',
#  'afflict',
#  'afforable',
#  'afford',
#  'affordability',
#  'affordable',
#  'affordably',
#  'aficianado',
#  'aficienado',
#  'aficionado',
#  'afire',
#  'afloat',
#  'afoot',
#  'aforementioned',
#  'afoul',
#  'afraid',
#  'afresh',
#  'africa',
#  'african',
#  'africans',
#  'africas',
#  'afrikaner',
#  'aft',
#  'afterburner',
#  'afterflavor',
#  'afterglow',
#  'afterlife',
#  'aftermarket',
#  'aftermath',
#  'afternon',
#  'afternoon',
#  'afternoonbut',
#  'afternooneither',
#  'afternote',
#  'afterntaste',
#  'aftershock',
#  'aftertaste',
#  'aftertastejuicy',
#  'afterthought',
#  'aftertone',
#  'afterward',
#  'afterwards',
#  'aftican',
#  'agassac',
#  'agate',
#  'agave',
#  'age',
#  'ageabiity',
#  'ageability',
#  'ageabilty',
#  'ageable',
#  'ageabledrink',
#  'ageand',
#  'agebut',
#  'aged',
#  'agedgive',
#  'agedin',
#  'agedoffer',
#  'agedrink',
#  'agefive',
#  'agegive',
#  'ageing',
#  'agelet',
#  'agemaybe',
#  'agemore',
#  'agency',
#  'agenda',
#  'agent',
#  'ageor',
#  'ager',
#  'ages',
#  'agethe',
#  'agethere',
#  'agetwo',
#  'ageworthiness',
#  'ageworthy',
#  'ageworthyfor',
#  'agfe',
#  'aggresively',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'aggressiveness',
#  'agile',
#  'agility',
#  'aging',
#  'aginga',
#  'agingall',
#  'agingallow',
#  'agingalthough',
#  'agingand',
#  'agingdrink',
#  'agingfive',
#  'agingfour',
#  'aginggive',
#  'agingmaybe',
#  'agingripe',
#  'agingthe',
#  'agingthree',
#  'agingtry',
#  'agingup',
#  'agiorgitiko',
#  'agiorgitikos',
#  'agiorgitko',
#  'aglianco',
#  'aglianico',
#  'aglianicothat',
#  'agnolotti',
#  'ago',
#  'agoancient',
#  'agood',
#  'agostina',
#  'agoston',
#  'agrapart',
#  'agrario',
#  'agree',
#  'agreeable',
#  'agrelo',
#  'agressively',
#  'agricoltori',
#  'agricultural',
#  'agriculture',
#  'agrigento',
#  'agrinatura',
#  'agroargento',
#  'agua',
#  'agueira',
#  'aguia',
#  'aguila',
#  'agustin',
#  'agustinos',
#  'ah',
#  'ahead',
#  'aheadbut',
#  'ahi',
#  'ahon',
#  'ai',
#  'aia',
#  'aid',
#  'aidil',
#  'aids',
#  'aigrots',
#  'aiken',
#  'aikens',
#  'aim',
#  'aimless',
#  'aimlessly',
#  'aine',
#  'aiolo',
#  'air',
#  'airborne',
#  'aircraft',
#  'aire',
#  'airen',
#  'aires',
#  'airfield',
#  'airiness',
#  'airing',
#  'airlie',
#  'airline',
#  'airplanemostly',
#  'airtime',
#  'airy',
#  'aix',
#  'ajoute',
#  'aka',
#  'akin',
#  'akiyoshi',
#  'al',
#  'alabaster',
#  'alain',
#  'alamitos',
#  'alamos',
#  'alan',
#  'alana',
#  'alance',
#  'alarid',
#  'alario',
#  'alarm',
#  'alarming',
#  'alary',
#  'alas',
#  'alaska',
#  'alastro',
#  'alavarinho',
#  'alavesa',
#  'alayt',
#  'alazan',
#  'alba',
#  'albada',
#  'alban',
#  'albana',
#  'albanello',
#  'albar',
#  'albarei',
#  'albarella',
#  'albarino',
#  'albarinos',
#  'albarola',
#  'albarossa',
#  'albeggio',
#  'albeit',
#  'albera',
#  'alberdi',
#  'alberello',
#  'alberic',
#  'albert',
#  'alberta',
#  'alberto',
#  'albi',
#  'albilla',
#  'albillo',
#  'albinea',
#  'albino',
#  'albis',
#  'albo',
#  'albrecht',
#  'alcamo',
#  'alcance',
#  'alcar',
#  'alchemist',
#  'alchemy',
#  'alchol',
#  'alcholic',
#  'alcineo',
#  'alcohol',
#  'alcohola',
#  'alcoholat',
#  'alcoholbut',
#  'alcoholfeature',
#  'alcoholic',
#  'alcoholicdespite',
#  'alcoholin',
#  'alcoholized',
#  'alcoholjust',
#  'alcoholmaybe',
#  'alcoholnearly',
#  'alcoholthe',
#  'alcoholthis',
#  'alcoholunusually',
#  'alconde',
#  'alconte',
#  'aldegheri',
#  'aldegheris',
#  'alder',
#  'alderbrook',
#  'alderpoint',
#  'ale',
#  'aleatico',
#  'alejandro',
#  'alentejano',
#  'alentejo',
#  'alentejoand',
#  'alentejobut',
#  'alentejojust',
#  'alentejos',
#  'aleramico',
#  'alert',
#  'alessandria',
#  'alessandrias',
#  'alessandro',
#  'alessio',
#  'alex',
#  'alexandar',
#  'alexander',
#  'alexandra',
#  'alexandre',
#  'alexandria',
#  'alexandrine',
#  'alfa',
#  'alfalfa',
#  'alfaspiga',
#  'alfio',
#  'alfred',
#  'alfredo',
#  'alfreds',
#  'alfrocheiro',
#  'alfrocheiroare',
#  'alfrochiero',
#  'algae',
#  'aliancas',
#  'aliara',
#  'alicante',
#  'alicanteshow',
#  'alices',
#  'alicias',
#  'alien',
#  'alienor',
#  'alighieri',
#  'align',
#  'aligned',
#  'alignment',
#  'aligote',
#  'alike',
#  'alion',
#  'aliquorous',
#  'aliso',
#  'alisos',
#  'alit',
#  'alita',
#  'alive',
#  'alizarine',
#  'alkaline',
#  'alkalinegive',
#  'alkalinity',
#  'alkoomis',
#  'alla',
#  'allamatriciana',
#  'allan',
#  'allarrabbiata',
#  'alldepth',
#  'alle',
#  'alleanza',
#  'allegedly',
#  'allegiance',
#  'allegrini',
#  'allegrinis',
#  'allelegance',
#  'allemands',
#  'allen',
#  'allende',
#  'allens',
#  'alleviate',
#  'alley',
#  'allfocus',
#  'alliance',
#  'allid',
#  'allied',
#  'allit',
#  'allium',
#  'allmore',
#  'alloro',
#  'allotment',
#  'allow',
#  'allowss',
#  'allpossesse',
#  'allram',
#  'allramand',
#  'allsappy',
#  'allspice',
#  'allspiceit',
#  'allthe',
#  'allude',
#  'allure',
#  'alluring',
#  'alluringly',
#  'allusion',
#  'alluvial',
#  'alluvium',
#  'ally',
#  'alma',
#  'almas',
#  'almaterra',
#  'almaviva',
#  'almeida',
#  'almon',
#  'almond',
#  'almondin',
#  'almondine',
#  'almondlike',
#  'almondsand',
#  'almondsit',
#  'almondskin',
#  'almondy',
#  'almost',
#  'almosty',
#  'aloe',
#  'aloft',
#  'alois',
#  'alone',
#  'along',
#  'alongside',
#  'alonside',
#  'aloof',
#  'aloofness',
#  'alorna',
#  'alornas',
#  'alot',
#  'aloud',
#  'aloxe',
#  'alpha',
#  'alphonse',
#  'alpille',
#  'alpine',
#  'alps',
#  'alread',
#  'already',
#  'alright',
#  'als',
#  'alsace',
#  'alsatian',
#  'also',
#  'alsoa',
#  'alsothoroughly',
#  'alta',
#  'altair',
#  'altairs',
#  'altamira',
#  'altano',
#  'altare',
#  'alte',
#  'altemuraone',
#  'altenberg',
#  'alter',
#  'alteration',
#  'alternate',
#  'alternately',
#  'alternative',
#  'alternatively',
#  'altesino',
#  'altesinos',
#  'although',
#  'altimus',
#  'altimusa',
#  'altitude',
#  'alto',
#  'altocedros',
#  'altogether',
#  'altoid',
#  'altos',
#  'altosur',
#  'altough',
#  'altrovino',
#  'altum',
#  'altuve',
#  'alum',
#  'alvarelhao',
#  'alvarinho',
#  'alvaro',
#  'alvear',
#  'always',
#  'alwyn',
#  'alzatura',
#  'amabile',
#  'amadieus',
#  'amador',
#  'amalfi',
#  'amalgam',
#  'amalgamate',
#  'amalgamation',
#  'amalgmated',
#  'amalie',
#  'amancaya',
#  'amancio',
#  'amandorlato',
#  'amant',
#  'amantis',
#  'amanzio',
#  'amaranto',
#  'amarela',
#  'amarena',
#  'amaretto',
#  'amaro',
#  'amarone',
#  'amaronebut',
#  'amaronenot',
#  'amaroneslush',
#  'amas',
#  'amass',
#  'amateur',
#  'amatriciana',
#  'amaurice',
#  'amavi',
#  'amaze',
#  'amazed',
#  'amazing',
#  'amazingly',
#  'ambar',
#  'ambassador',
#  'ambassadorial',
#  'amber',
#  'amberthis',
#  'ambience',
#  'ambient',
#  'ambiguity',
#  'ambiguous',
#  'ambition',
#  'ambitious',
#  'ambitiously',
#  'ambivalent',
#  'amble',
#  'ambre',
#  'ambrogio',
#  'ambroise',
#  'ambrosan',
#  'ambrosia',
#  'ambrosiac',
#  'ambullneos',
#  'amd',
#  'ame',
#  'amelia',
#  'amelie',
#  'ameliorate',
#  'amenability',
#  'amenable',
#  'america',
#  'american',
#  'americanbut',
#  'americans',
#  'americaprobably',
#  'americas',
#  'amerigo',
#  'amerikus',
#  'amerique',
#  'ameritage',
#  'amiable',
#  'amiata',
#  'amicable',
#  'amicably',
#  'amici',
#  'amicis',
#  'amicus',
#  'amid',
#  'amidst',
#  'amigas',
#  'amisfield',
#  'amiss',
#  'amity',
#  'amitys',
#  'amke',
#  'ammo',
#  'ammonia',
#  'ammonite',
#  'ammons',
#  'amok',
#  'among',
#  'amongae',
#  'amongst',
#  'amontillado',
#  'amorphous',
#  'amount',
#  'amour',
#  'amp',
#  'ampe',
#  'ampelographers',
#  'ampelos',
#  'amphitheater',
#  'amphitheatreregarde',
#  'amphora',
#  'ample',
#  'ampleness',
#  'amplified',
#  'amplify',
#  'amplitude',
#  'amplus',
#  'amply',
#  'ampuis',
#  'amuse',
#  'amusing',
#  'amusingly',
#  'amy',
#  'amylic',
#  'amyndeon',
#  'ana',
#  'anagram',
#  'anakenas',
#  'anakota',
#  'analog',
#  'analogy',
#  'analysis',
#  'analytical',
#  'analyze',
#  'anam',
#  'anathema',
#  'ance',
#  'ancellotta',
#  'ancenis',
#  'ancestor',
#  'ancestrale',
#  'ancestry',
#  'ancho',
#  'anchor',
#  'anchoring',
#  'anchovy',
#  'ancien',
#  'ancienne',
#  'ancient',
#  'ancillary',
#  'ancona',
#  'andalmond',
#  'andalusia',
#  'andat',
#  'andau',
#  'andbutter',
#  'andcherry',
#  'andconcentrated',
#  'andcrushe',
#  'andd',
#  'andeluna',
#  'andelunas',
#  'anderson',
#  'andes',
#  'andfaintlyblackberry',
#  'andflat',
#  'andina',
#  'andis',
#  'andiss',
#  'andlau',
#  'andor',
#  'andpineapple',
#  'andre',
#  'andrea',
#  'andreas',
#  'andres',
#  'andretti',
#  'andrew',
#  'andrews',
#  'andrus',
#  'ands',
#  'andsoft',
#  'andtangerine',
#  'andthere',
#  'andunusual',
#  'andvanilla',
#  'andy',
#  'andyesageworthy',
#  'andyesbubbly',
#  'ane',
#  'anearthiness',
#  'anejon',
#  'anemic',
#  'anette',
#  'anfora',
#  'angel',
#  'angeles',
#  'angelesa',
#  'angeli',
#  'angelica',
#  'angeline',
#  'angelini',
#  'angelinis',
#  'angelo',
#  'angelus',
#  'angialis',
#  'angimbe',
#  'angiolina',
#  'anglaise',
#  'angle',
#  'angled',
#  'angludet',
#  'angludetpositive',
#  'angosto',
#  'angove',
#  'angoves',
#  'angry',
#  'angst',
#  'angular',
#  'angularity',
#  'anima',
#  'animal',
#  'animale',
#  'animales',
#  'animalistic',
#  'animality',
#  'animate',
#  'animated',
#  'anise',
#  'aniseallie',
#  'anisebut',
#  'aniseed',
#  'anisette',
#  'anita',
#  'anjou',
#  'ann',
#  'anna',
#  ...]

# %%
vectorizer2 = CountVectorizer(analyzer='word', ngram_range=(10,10))
X2 = vectorizer2.fit_transform(corpus)

# %%
vectorizer2.get_feature_names()
# Out:
# ['aa tremendous value rise plump yet fresh vibrant raspberry cherry',
#  'aalto one several small project lead former vega sicilia head',
#  'aand sugar finish long refreshing mark pronounce dry minerality drink',
#  'aaron pott blend merlot cabernet franc cabernet sauvignon minerally herbaceous',
#  'abacela continue prove southern oregon really westernmost province spain not',
#  'abacela evoke spanish nuance many wine extend even syrah not',
#  'abacela found premise unique site central oregon perfectly suit tempranillo',
#  'abacela great year also substantial authoritative deeply drive flavor red',
#  'abacela produce dense mineral drive style viognier vertically layer mix',
#  'abacela remain single iconoclastic winery entire northwest pioneer unusual estate',
#  'abacela showcase spicy peppery side grape may young vine simply',
#  'abacela single handedly revolutionize winemaking southern oregon introduce iberian variety',
#  'abacela tenth vintage tempranillo suggest time call experiment success savory',
#  'abacela vineyard zs night day mostly merlot cabs franc sauvignon',
#  'abacelas albarino racy wine excellent varietal character fruit flavor suggest',
#  'abacelas wine appreciate effort varietal cab franc wine could benefit',
#  'abadal label catalonia produce hit upon hit blend merlot cabernet',
#  'abadal line seem commit serious aroma flavor support honest structure',
#  'abadal maker true terroir wine succeed way often disappoint blend',
#  'abadal wine cabernet sauvignon merlot blend get side old world',
#  'abadia de san campio albarino wine also feature loureira caino',
#  'abadia retuerta weak wine single vineyard syrah lush loaded burst',
#  'abandon effort varietal sweet peach mild lychee spice aroma open',
#  'abandon sangiovese quest mw persist case polished easy wine plenty',
#  'abandon stewed black plum sugar plum aroma meet vanilla strawberry',
#  'abandon thus name trace salinity throughout lurk layer asian spice',
#  'abandon wine show old fashioned ruggedness kind face tannin grapeskin',
#  'abbaye de morgeot vineyard equally suited pinot noir chardonnay able',
#  'abbey build wine modern clean plush drive ripe fruit spice',
#  'abbey crown softly roll hill wine pack tightly bright cherry',
#  'abbey drappier top vintage show structure tense character wine drappier',
#  'abbey la ferte produce good givry wine great structure firm',
#  'abbey ridge bottling pizzazz good release beautiful expression grape grow',
#  'abbey see difficult year thankfully vine remain productive gorgeous rich',
#  'abbey wine overall young intensely concentrated merlot star year quite',
#  'abbey would serve aroma lightly smoky spicy like white pepper',
#  'abbinare miscela bit cabernet sauvignon add splash syrah otherwise bordeaux',
#  'abboccato orvieto classico mean wine enough residual sugar make taste',
#  'abbona dogliani another winner dense deeply extract wine flawlessly exhibit',
#  'abbott belong anyones short list washingtons talented winemaker supple dense',
#  'abbott claim bit chocolaty flavor full spicy cherry fruit core',
#  'abbott outdo immediately appealing send rush black cherry cassis fruit',
#  'abbott source fruit merlot estate heather hill vineyard old vine',
#  'abbotts winemaking old vine fruit bring subtle grace note wine',
#  'abc though less delicate elegant rather accessible perhaps less acidic',
#  'abeille family chateau mont redon chateauneuf du pape wine delicious',
#  'abeilles traditional rhone blend offering marry viognier roussanne result medium',
#  'abeja chardonnay certain hit target kobe bryant slam dunk style',
#  'abeja chardonnay memorable style build around yummy barrel flavor toast',
#  'abeja dark juicy dense smoky layered tight pepper bacon coffee',
#  'abeja style complex stylish buttery striking fruit laden wine long',
#  'abeja thick black redolent new french oak close napa valley',
#  'abeja wine offer exceptional quality price across entire lineup case',
#  'abeja winemaker john abbott source fruit merlot estate heather hill',
#  'abejas estate grow viognier back rich mouthfeel high acid generous',
#  'abejas john abbott belong anyones short list washingtons talented winemaker',
#  'abejas main production center upon three cabernet one source throughout',
#  'abejas syrah estate grow fragrant scent fresh green herb hint',
#  'abelis carthago enigmatic lowest price lui balanced complete wine william',
#  'abelis carthagos top wine fight bull also tough enjoy overripeness',
#  'abernathy vineyard leather mocha oak smoke vanilla deep cherry nose',
#  'aberrant cellar pale copper hue rich full bodied load flavor',
#  'abetina madrona vineyard among aromatic dense toasty deftly blend aroma',
#  'abetina one acre size young wine share similar high acid',
#  'abetina subtle depth share similar weight balance promise good thing',
#  'ability abacela evoke spanish nuance many wine extend even syrah',
#  'ability absorb beautiful toasted quality associate oak age sophisticated smooth',
#  'ability age fruit definitely second place although concentrate black fruit',
#  'ability age well applause dehour indicate disgorgement date back label',
#  'ability age well bottle sample taste young need least year',
#  'ability blend crispness richness elegant version variety round lemon tart',
#  'ability bottle smooth velvety texture show sign maturity many complex',
#  'ability bouquet deal strawberry raspberry mint sage mouth hard tannin',
#  'ability coax black cherry pomegranate allspice flavor wrap voluptuous mouthfeel',
#  'ability convey marshmallow roasting campfire full bodied lush rich fruit',
#  'ability deliciously drinkable yet stuffing cellar dry crisp full bodied',
#  'ability deliver big mouthfille flavor without suggestion heat heaviness scent',
#  'ability enjoy underlie blackberry currant flavor not immediately enjoyable estate',
#  'ability fill divot every kind gentle dry rich complex pinot',
#  'ability find superb fruit raise fine wine sell fair price',
#  'ability get grape ripe blackberry currant yet fruit pull back',
#  'ability grow array grape particularly red variety incognito amalgam syrah',
#  'ability grow great fruit show wine syrah black color boastful',
#  'ability grow nicely mannered sauvignon blanc six sigma deftly achieve',
#  'ability gruner veltliner wine still fresh lively line acidity give',
#  'ability juicy approachable powerful tannin potential age cassis raspberry black',
#  'ability little appellation middle salinas valley santa lucia highlands ripen',
#  'ability make good cab franc one foot flavor red berry',
#  'ability marry richness lightness well display auslese aroma funky stinky',
#  'ability obtain ripe naturally tart mixed fruit flavor avoid join',
#  'ability offer soft round cherry tone back typical note forest',
#  'ability pack plum berry fruit still integrate solid tannin need',
#  'ability pair food thank creamy fruit drive nose overall smoothness',
#  'ability pair fresh food fish villa matilde present clean pristine',
#  'ability pair mediterranean food aged month oak estate top wine',
#  'ability pair pasta meat base dish finish drive smooth tannin',
#  'ability perfectly balance showcase exact ripeness fruit leave subtle grace',
#  'ability perfectly ripen fruit maintain complete balance flavor cherry raspberry',
#  'ability play card deal wine dry rich tannin frame blackberry',
#  'ability produce deeply color wine sousao make wine rough edge',
#  'ability produce dry complex syrah interest sophistication find layer blackberry',
#  'ability produce rich wine acidity still balanced ripe yellow fruit',
#  'ability produce ripe gentle red wine immediately appealing nice earthiness',
#  'ability produce spicy savory style shiraz blend aroma tar singe',
#  'ability provide huge flavor personality retain freshness high level acidity',
#  'ability provide lush richness within balanced context dark thick open',
#  'ability red bordeaux grape time deftly show enfant terrible cab',
#  'ability ripen easily wine touch spice go complex blend ripe',
#  'ability ripen fruit preserve vital acidity cherry cola spice vanilla',
#  'ability ripen fruit tannin gentle thoroughly dry wine rich black',
#  'ability ripen grape anyone show deep flavor cherry puree mocha',
#  'ability ripen magnificent vintage result wine unusual tension ripe black',
#  'ability ripen pinot grape hugeness somehow stay varietally balanced red',
#  'ability ripen red grape little soft side robust tannin provide',
#  'ability ripen red wine even cool vintage flood mouth lush',
#  'ability slightly oxidize oak ferment white redolent stone fruit mature',
#  'ability take disparate lot make harmonious beautiful cabernet dry softly',
#  'ability take varietal flavor soil wine show richness opulence still',
#  'ability thrive napa valley good result year year dry intricate',
#  'ability wash palate clean wine also enough creaminess stay power',
#  'ability wine charm open lively spice dry apricot work together',
#  'ability work great fruit make interesting wine savory petite sirah',
#  'able achieve awesomely rich blackberry blueberry cherry jam cassis liqueur',
#  'able age give balance wealth cherry pomegranate persimmon rhubarb fruit',
#  'able appreciate wave cherry blackberry currant cola new oak add',
#  'able bring character cool cote de lechet typical tight mineral',
#  'able bring good year wine retain crispness minerality almost chalky',
#  'able bring naturally perfume fruitiness riesle feel terroir tangy minerally',
#  'able craft ripe fruit keep varietal character cabsearth herb touch',
#  'able distinguish range domaine wine gevrey luxuriously perfume finely structure',
#  'able express powerful concentrated need time develop although direction wine',
#  'able find nice equilibrium oppose personality leathery akin pipe tobacco',
#  'able find something good nose medicinal cherry drive palate good',
#  'able find success cold vintage sauvignon blanc wine dry high',
#  'able handle fact wood mesh seamlessly bright intense cherry pomegranate',
#  'able hit high note wine enjoyable minimum make incredible partner',
#  'able hold sophisticated wine back long still sell buck wine',
#  'able jump board wine since debut three harvest ago nose',
#  'able keep good cabernet high elevation site reflect tight somewhat',
#  'able keep intensely sweet rich wine heavy cloying dry apricot',
#  'able maintain brand quality even production ramp case remarkable feat',
#  'able make bone dry wine without lose rich fruit character',
#  'able make fascinating blend combination chardonnay neuburger weissburgunder welschriesle mix',
#  'able make stunning riserva hot forward vintage open aroma forest',
#  'able make use figeac name small estate offer attractive fruity',
#  'able manage well past one expect find commensurate weight density',
#  'able open glass serve well midweek house wine staple large',
#  'able produce attractive forward wine like one ripe soft structure',
#  'able produce dense dusty tannic wine fine black fruit wine',
#  'able produce fresh fruity wine like one spice citric blend',
#  'able produce intense fruit even simplest wine fresh concentrated summer',
#  'able produce mineral grapefruit flavor wine good quantity touch caramel',
#  'able produce powerful wine toasty ripe fruit power yeast flavor',
#  'able produce ripe rich wine like contrast tight steely texture',
#  'able produce serious aged tawnie fresh ripe fig flavor wine',
#  'able produce sumptuous wine typically rich powerful structured solid blackberry',
#  'able produce surprisingly fresh fruity white like despite heat dry',
#  'able produce wine combine great sense style weight along fresh',
#  'able purchase mature bottle gigonda like one pack savory element',
#  'able report much improve dosage lower considerable freshness crispness apple',
#  'able resist pour multiple glass soft spicy marvelous raspberry cherry',
#  'able show age long cask age flavor still fig honey',
#  'able stand beside expensive one make cabernet sauvignon petit verdot',
#  'able stand spicy appetizer crisp long finish proceed donate restoration',
#  'able tell difference light bodied zin also pinot day heavy',
#  'able track sweet luscious spatlese citrus custard note mark nose',
#  'able turn good wine giveaway price wine basically dry crisp',
#  'ably balance bountiful acid floral note lead nose follow hint',
#  'ably combine ample fruit cool minerally note make complex tongue',
#  'ably marry meaty savory note tart berry plenty weight palate',
#  'ably reflect warm vintage yet despite lushness wine not come',
#  'ably show mosel riesling array fruity dry flavor range peach',
#  'ably wrap anise green apple citrus fruit cloak austere minerality',
#  'abnormal aroma spiced fruit cardamom nutmeg palate thick along edge',
#  'abnormal variety rias baixas region flavor spiced apple finish spice',
#  'abnormal white wine standard oily aroma smoke meat air freshener',
#  'abnormally bright lively paixar normally dark full bodied type mencia',
#  'abnormally friendly structure solid make average wine class acidity mellow',
#  'abnormally structure pinot noir producer firm tannin crisp acid highlight',
#  'aboard lush creamy mouthfeel finish long supple glide easily away',
#  'aboard minerally frame kerosene petrol note dominate end burst fresh',
#  'aboard rich viscous wine not not heavy warm despite alcohol',
#  'aboard round mouthfille wine bolster creamy textured tannin nothing dislike',
#  'abondante fine wine pair pizza offer interesting flavor berry stone',
#  'abondante mix cherry candy tropical flavor full bodied robust ready',
#  'abound accent cocoa foliage lightweight round well structure moderate finish',
#  'abound accent milk chocolate thyme eucalyptus hint grapefruit oil add',
#  'abound accent touch cigar box vanilla palate ripe creamy textured',
#  'abound along licorice tar whiff iodine tightly wind syrah stuffing',
#  'abound also sort foresty fern influence nose zingy mouth savory',
#  'abound balanced refreshing wine element cucumber celery salad green join',
#  'abound berry fruit tannin soft supple wine drink well right',
#  'abound bing cherry flavor depth earthy goodness new mendocino county',
#  'abound bouquet flavor pepper leathery spice add intrigue palate medium',
#  'abound bouquet follow way long close black fruit flavor present',
#  'abound bouquet mouth easy drink chard touch honey linger medium',
#  'abound bouquet mouthfeel full not fat medium acidity keep fruit',
#  'abound bouquet prominent acidity lift mouth provide vibrancy rich fruit',
#  'abound bouquet wine lift superattractive aroma fudgy brownie fruit transition',
#  'abound brisk slightly puckery bordeaux blend medium bodied style refreshing',
#  'abound butter toast richness oak appeal upfront simple popular sweetness',
#  'abound classic gewurztraminer ebulliently perfume slightly brawny footprint bold stroke',
#  'abound clean fresh mouthfeel hint sweetness not enough render incompatible',
#  'abound cool vintage lead low yieldsunder two ton per acre',
#  'abound deep red wine firmly structured approachable potential age gracefully',
#  'abound delicate yet penetrate wine clean fresh add highlight citrus',
#  'abound delightfully rich sweet lively fresh nicely balanced racy acidity',
#  'abound demonstrate balance vintage ageability spring mountain wine cellar year',
#  'abound distinctively acidic underpinning sangiovese light strawberry cherry fruit gently',
#  'abound dominating note sour cherry persimmon cinnamon spice sweet oak',
#  'abound dr franks lovely bargain salmon run although full bodied',
#  'abound dry fruity floral characteristic salmon peach color texture requisite',
#  'abound dry interesting blend syrah grenache petite sirah viognier fruit',
#  'abound dry merlot pretty tannic gum stick astringency unlikely age',
#  'abound dry surprisingly lean chardonnay hint sweet cream vanilla brisk',
#  'abound dry tannic cabernet palate little sharp texture unlikely age',
#  'abound dry tannic cabernet sauvignon show napa valley class case',
#  'abound dry tannic merlot feel bit rough palate let breathe',
#  'abound earth dry cherry anise roasted meat herb aroma structure',
#  'abound earth dry plum flavor palate keep lively decent acidity',
#  'abound easy drink red accent black pepper dry carnation petal',
#  'abound elegant long island merlot make petit verdot touch austere',
#  'abound energy drive black raspberry fruit accent earthy loam fennel',
#  'abound especially vanilla fruit seem bit overshadowed point time tannin',
#  'abound expressive flavor generosity meet lemony freshness utterly moreish seductive',
#  'abound fine grain tannin lead masterfully cocoa dust finish complex',
#  'abound finish especially tight dry tannin complex mineral earth element',
#  'abound firmly structure dry wine tannin fore plus heavy toast',
#  'abound flavor black plum skin dominate palate coat mouth firm',
#  'abound flavor blackberry cherry pie filling give direct candy taste',
#  'abound follow nutty sweet spice flavor finish thankfully enough acid',
#  'abound freshness palate mark wine delicious difficult cellar drink five',
#  'abound full creamy mouthfeel round fresh pleasing sprinkle cinnamon spice',
#  'abound glenora dry pinot noir rise dry concentration candy sweet',
#  'abound goodness grape rather woody flavor barrel sweet seeming fruit',
#  'abound grenache base blend also note orange zest grill prosciutto',
#  'abound herbal glimmer white tea honeysuckle background add depth interest',
#  'abound high impact refined gewurztraminer dry delicately frame refreshing sip',
#  'abound immediately behind aroma however load spice smoke tar drink',
#  'abound juicy easy go chardonnay lack oak age highlight youthful',
#  'abound juicy primary cabernet franc forward fruity plump rich texture',
#  'abound lean concentrated pinot gris dry spry palate hone minerality',
#  'abound light refresh riesle offer glimpse white peach lime slate',
#  'abound load palate flavor peach cream lemon meringue thoroughly delicious',
#  'abound lovely tension texture great tart citrus note linger long',
#  'abound luscious peach honeysuckle perfume palate flavor veer toward peach',
#  'abound lush fruity yet elegantly structure riesle medium sweet deliciously',
#  'abound make mouthfilling not overly complex wine finish touch alcoholic',
#  'abound medium bodied blend whose mouthfeel full spicy balanced full',
#  'abound merlot easy drink burger enchilada rib slather barbecue sauce',
#  'abound mild acid sign ripeness wine alcohol finish crisp minerality',
#  'abound mix citrus rind candy must chill enjoy forward simple',
#  'abound moment fruit seem hidden perhaps need bottle age balance',
#  'abound mouth full slightly fat moderate acidity medium length smoky',
#  'abound mouthfeel suave tangy finish show dusty tannin big chocolate',
#  'abound nose along aroma licorice fennel seed raspberry palate offer',
#  'abound nose alongside soft vanilla purple floral accent cherry mulberry',
#  'abound nose back dark juicy black raspberry full firmly structure',
#  'abound nose bordeaux style blend aroma transition dominate flavor palate',
#  'abound nose dry riesling palate mineral restrained lemon lime acidity',
#  'abound nose flavor fresh pick black berry fill medium weight',
#  'abound nose flavor lemon curd lemon pith bring nuance palate',
#  'abound nose interesting note yellow flower soft toast add depth',
#  'abound nose kirsch pepper allspice unfold palate creamy lush mouth',
#  'abound nose medium weight mouth provide dry berry flavor lace',
#  'abound nose mouth frame note vanilla creme purple flower light',
#  'abound nose mouth glimmer peppery game linger end big firm',
#  'abound nose mouth linger well close alongside touch fudgy chocolate',
#  'abound nose mouth long finish carry char woody edge even',
#  'abound nose mouth long mouthwatering finish evolve ripe fruit flavor',
#  'abound nose mouth remain lengthy close weight density try cream',
#  'abound nose mouth structure plump juicy low tannin zippy acidity',
#  'abound nose palate accent mocha dry spice hint herbaceousness plush',
#  'abound nose palate blueberry black plum violet coffee granule hint',
#  'abound nose palate creamy texture like crushed velvet long brambly',
#  'abound nose palate easy pleasing accessible wine fine tannin medium',
#  'abound nose palate lively floral character add lift depth bouquet',
#  'abound nose palate meet tangy grapefruit zestiness ultralight refreshing drink',
#  'abound nose palate mouthfeel plush creamy medium tannin texture like',
#  'abound nose palate solid peach pit nuttiness linger medium length',
#  'abound nose palate wine medium body round smooth ample freshness',
#  'abound nose plucky red black cherry spice pepper flavor follow',
#  'abound nose wine balance expressive garrigue primarily rosemary thyme ripe',
#  'abound not quite dry riesling mouth feel bit confected much',
#  'abound oaky cabernet little one dimensional high alcohol drink soon',
#  'abound offset firm mineral element balanced wine zesty aciditythe long',
#  'abound palate borderline medicinal due extreme ripeness like rich sun',
#  'abound palate counter brisk clean freshness wine enlivening palate juicy',
#  'abound palate give weight viscosity crisp acidity need liven thing',
#  'abound palate lightweight soft dusty tannin solid finish kiss oak',
#  'abound perfumed aroma fruit totally texture terroir white currant fruit',
#  'abound pert fruity pinot grigio despite light body expansive silken',
#  'abound play pervaded freshness hold within frame fine ever slightly',
#  'abound pretty flower sweet peach pear aroma mingle toasted oak',
#  'abound radiant wine palate dole white peach yellow pear nectarine',
#  'abound rather simple lbv clean well make not show much',
#  'abound refreshingly dry chardonnay satisfyingly juicy tart penetrate palate flavor',
#  'abound rich dark fruit oak age eleve en futs de',
#  'abound rich pack fruit along seductive flavor age new french',
#  'abound robustly fruity yet elegant bordeaux style wine high proportion',
#  'abound silky pinot noir oak drive note buttered toast wood',
#  'abound simple attractive wine fragrant fruity light texture fresh acidity',
#  'abound sparkler almost dry sweetness fine burst citrusy acidity help',
#  'abound spice ripe pear peach mango fruit dense texture come',
#  'abound structure soft mouthfeel even joyous killer barbecue red anything',
#  'abound structured red big bold palate offer ripe black cherry',
#  'abound subtext light clean earth tannin modest acid natural subdued',
#  'abound supple velvet texture merlot mouthfille rich brisk cranberry acidity',
#  'abound support nicely solid not hard acid tannic structure balanced',
#  'abound sweet tart nectarine peach tangerine flavor primary fresh uncomplicated',
#  'abound tart dark side force rule many love undeniably handsome',
#  'abound taste late pick almost porty currant coffee chocolate flavor',
#  'abound tease streak anise clove espresso lush precise excellent length',
#  'abound throughout balanced straightforward wine simple yet attractive use apertif',
#  'abound throughout grace fruit element honeydew bake apple peach pit',
#  'abound throughout textbook mosel kabinett sun kiss apricot peach burst',
#  'abound touch honey finish two third source excellent hyland vineyard',
#  'abound underneath tart fruit carry green note decant time prior',
#  'abound velvety texture full mouth long evolve finish end divine',
#  'abound wild berry currant tobacco cola tabasco exotic spice great',
#  'abound wine remain lively ample acidity smooth though dense tannin',
#  'abound wrap around tart lightly spicy note apple interesting combination',
#  'abound wrap firm muscular polished package fine grain tannin dark',
#  'abound zesty chardonnay supple quite creamy palate pristine lemon pear',
#  'aboundchalk graphite granite underscore bright cranberry currant fruit strikingly pure',
#  'abouriou grape blend herbal spicy round character beef weight tannin',
#  'abouriou grape give structured firm wine tannin juicy black fruit',
#  'abouriou powerful mint tar perfumed rich structured dense firm tannin',
#  'abracadabra everyday blend receive care vineyard winery new vintage sappy',
#  'abrasive acidity push herbal lean flavor blackberry chocolate spice turn',
#  'abrasive aggressive generic citrus flavor pithy finish rough wine albarino',
#  'abrasive berry herbal flavor sour side finish nothing bring around',
#  'abrasive blacken ripe flavor dark berry fruit back peppery spice',
#  'abrasive cheek mediocre flavor profile outside look great nice bottle',
#  'abrasive choppy mouthfeel oaky flavor creamy berry fruit adequate well',
#  'abrasive feel warm bitter peppery plum cherry flavor leave heat',
#  'abrasive feeling malbec thing taste short snappy red fruit flavor',
#  'abrasive finish rocky tannin accent chocolate cinnamon hold another couple',
#  'abrasive flavor good mix graphite olive iron filing coffee groundsmore',
#  'abrasive give dark lean aroma show baked black fruit flavor',
#  'abrasive herbal palate bring hard acidic feel high toned herbal',
#  'abrasive herbal plum flavor minty forceful finish register hard tannic',
#  'abrasive herbal plum raspberry flavor set finish lightly green woody',
#  'abrasive herbal throughout blend cabernet sauvignon merlot syrah tempranillo descend',
#  'abrasive high acidity minty flavor herbal plum pie cherry tight',
#  'abrasive hollow midpalate green lean minty flavor blackberry plum finish',
#  'abrasive many toro prone blackberry root note sugar beet flavor',
#  'abrasive mouthfeel nothing smooth borderline overripe flavor baked plum blackberry',
#  'abrasive nose punch character feel fresh lean narrow traditional rioja',
#  'abrasive note dry apple citrus rich toasty yeast perk finish',
#  'abrasive palate herbal red berry flavor suggestive minty cranberry cherry',
#  'abrasive palate high acidity taste herbal plum medicinal raspberry gripping',
#  'abrasive palate unfold offer herbal flavor berry plum tannic scratchy',
#  'abrasive plum herb spice green tobacco flavor tart bit green',
#  'abrasive powerful flavor roasted plum tomato herbs finish grate tannin',
#  'abrasive scratchy palate blackberry milk chocolate flavor lead finish one',
#  'abrasive stemmy add burgundy like note essential pinot noir character',
#  'abrasive tannin hold wayward frame blueberry plum floral flavor finish',
#  'abrasive tannin strain flavor herbal berry leather finish earthy tannic',
#  'abrasive tannin sweet sticky woody black fruit flavor finish brown',
#  'abrasive tannin taste grill beef lemon peel toast cassis chocolate',
#  'abrasive tea herbal berry chocolaty oak flavor appeal spicy peppery',
#  'abrasive tongue mix oxidized flavor bitter citrus grassy accent finish',
#  'abrasive wine carry stony freshness finish not evolve persist cleanse',
#  'abrasiveness mouthfeel flavor earthy blackberry plum finish raisiny short heavy',
#  'abraxas make one traditional interpretation dark amber color pure aroma',
#  'abreu callado charity foundation dark black currant fruit big tannin',
#  'abreus vineyard st helena foothills complex soft open approachable colgin',
#  'abrigo particularly focus cru expression barolo really love cannubi boschis',
#  'abrigo treiso area lovely expression barbaresco immediate aroma cherry cassis',
#  'abroad burst open aroma dark berry spice leather tobacco generous',
#  'abroad even italy definitely worth keep eye blend cabernet sauvignon',
#  'abroad lungarotti work hard tame variety careful oak age low',
#  'abroad monte fante cru smell like opulent dessert creme brulee',
#  'abrupt drying finish lack vibrancy not enough fruit richness stand',
#  'abrupt edgy tannin quite good price give hour two decanter',
#  'abrupt feel good palate lack bit flow medicinal red berry',
#  'abrupt finish textural complexity oaky overlay fine charming wine mean',
#  'abrupt offer dry black cherry espresso grill sage not much',
#  'abrupt rustic tannin fantastic acidity fine give good five year',
#  'abruptly another shot brace acid ultimately toast sheer quality stand',
#  'abruptly firm astringent tannin finish tannic enjoy question whether resemble',
#  'abruptly wash astringent acidity many hour breathing fail open flavor',
#  'abruzzi medium gold color make think something go awry confirm',
#  'abruzzo central italy deliver amazing intensity opulence set particular vintage',
#  'abruzzo central italy offer beautifully intense aroma honeysuckle acacia flower',
#  'abruzzo deliver mature note peach round toasted note honey pear',
#  'abruzzo montepulciano expression show light informal side native variety soft',
#  'abruzzo offer sultry aroma spice currant dry raspberry along note',
#  'abruzzo plush aromatic layer toasted nut exotic fruit pineapple honeysuckle',
#  'abruzzo poise confident wine define aroma ripe blackberry leather polished',
#  'abruzzo puglia montepulciano primitivo sangiovese negroamaro malvasia soft luscious wine',
#  'abruzzo region central italy boast many unknown treasure among beautiful',
#  'abruzzo region central italy offer sun drench tone mature peach',
#  'abruzzo region central italy show load ripe fruit blackberry shading',
#  'abruzzo region full generous bouquet wild berry white cherry pomegranate',
#  'abruzzo region make hearty locally grow montepulciano grape expression open',
#  'abruzzo sophisticated barrique aged wine show enormous talent dedicate wife',
#  'abruzzo underline specific quality minded winemaking philosophy make italian region',
#  'abruzzo wine plush rich ripe cherry blackberry aroma back touch',
#  'abruzzo winemaking hearty pecorino open deep gold color tangy aroma',
#  'absence barrel influence wine rich complex tangerine apricot lime lemon',
#  'absence cloy jammy fruit give elegant sophisticated personality finish characterize',
#  'absence complexity really impress depth range berry currant licorice mocha',
#  'absence fruit show modest flavor cherry blackberry not seem like',
#  'absence fruit stand bone dry severe thin cherry skin cola',
#  'absence oak grape come mostly lodi touch monterey brighten crisp',
#  'absence oak influence flavor carry load intense note apricot meyer',
#  'absence residual sugar accentuate acidity make wine tart almost sour',
#  'absence richness chablis style wine mark mineral suggestion lemon lime',
#  'absence richness make acidity alcohol stand good wine something disappointment',
#  'absence structure accentuate ripeness give taste candy cherry licorice plus',
#  'absence structure make ripe pineapple jam vanilla custard flavor taste',
#  'absence structure make wine finish quick not allow age drink',
#  'absence subtlety sheer deliciousness tannin soft make ideal drink steak',
#  'absense variety trademark floral peach aromatic presage lack ripeness find',
#  'absent amid spicy hammer pool dark fruit tannin seem professionally',
#  'absent resin tar like flavor sometimes find instead absolutely pure',
#  'absent seem bit hole back wine open beautifully hit dead',
#  'absent vegetal tomato leaf character often strike oregon wine price',
#  'absolute balance powerful would line flirt gob jammy apricot yellow',
#  'absolute concentration dryness air aromatic lemon balm note add special',
#  'absolute delight drink rich fruity floral flavor ultrarefreshing acidity almost',
#  'absolute dryness crispness minerally depth something coldly metallic taste mouthfeel',
#  'absolute dryness palate ample generous deep seated fruit pear apple',
#  'absolute dryness serve accentuate tartness make clean razorsharp edge nice',
#  'absolute dryness tart acidity fuzzy edge tannin clearly well grow',
#  'absolute dryness zesty crispness tantalizing flavor make blend free run',
#  'absolute expert barrel aging oak toast dark chocolate spice clove',
#  'absolute gem respect languedoc produer gerard bertrand aroma draw immediately',
#  'absolute good rise grape oregon floral strawberry bouquet burst bottle',
#  'absolute home run pure dense cabernet flavor fill glass forward',
#  'absolute joy drink aroma deep penetrate include sweet milk chocolate',
#  'absolute joy drink great expression sonoma coast vineyard dryness acidity',
#  'absolute joy fragrant complex offer pleasure nose palate scent leaf',
#  'absolute lemon freshness pure linear totally toned major tart invigorating',
#  'absolute pleasure drink beautiful sicilian wine would pair shellfish crab',
#  'absolute pleasure drink especially fresh pasta top grated parmigiano cheese',
#  'absolute purity body taut bone dry finish clean lasting gorgeous',
#  'absolute purity concentration core dry structured wine strike wonderful balance',
#  'absolute riot mixed berry fruit scent flavor full lush dense',
#  'absolute showstopper waft honey mango grapefruit deeply concentrated wine saturate',
#  'absolute steal pomegranate blueberry black cherry cassis note lead full',
#  'absolute wonder accompany salmon croquette asparagus canape fish soup import',
#  'absolute zesty freshness lissom dry light bodied full flavor mellow',
#  'absolutely beautiful comprise silk satin brighten acidity drink yes age',
#  'absolutely beautiful first class cabernet drink really well balance ride',
#  'absolutely beautiful one good unoaked chardonnay market brim bright clean',
#  'absolutely beautiful white wine make bland ansonica chardonnay deliver rich',
#  'absolutely beautiful wine deep layer spice dark fruit licorice back',
#  'absolutely beautiful wine drink richness come price considerable alcohol color',
#  'absolutely beautiful wine make blend pinot bianco chardonnay picolit friuli',
#  'absolutely beautiful wine winery quietly great job cab make grape',
#  'absolutely bone dry zesty acidity subtle flavor lemon lime steely',
#  'absolutely burst scent flavor ripe cherry delicious wine amazing intensity',
#  'absolutely classic show region balance power elegance wild blackberry raspberry',
#  'absolutely decadent honeyed apricot pineapple creme brulee vanilla fudge flavor',
#  'absolutely decadently good combine attribute fine vintage fine parcel celebrate',
#  'absolutely delicious addictive dessert wine brisk acidity clean mouth offer',
#  'absolutely delicious barrel selection tandem different vineyard designate dazzle flashy',
#  'absolutely delicious cabernet rich tannin frame impeccably ripe jammy cassis',
#  'absolutely delicious chardonnay forward pineapple peach pear green apple honey',
#  'absolutely delicious cherry pomegranate spice wonderful earthiness ground silky complex',
#  'absolutely delicious classic napa balance show petite sirah momentum age',
#  'absolutely delicious dazzle show blackberry tart cherry pie sweet smoky',
#  'absolutely delicious drink clean crisp acidity opulent flavor tropical fruit',
#  'absolutely delicious find wish great structure offer wave raspberry cherry',
#  'absolutely delicious first rate chard veteran producer show pretty balance',
#  'absolutely delicious flood mouth rich flavor blackberry jam creme de',
#  'absolutely delicious forward almost jammy red cherry sweet rhubarb pie',
#  'absolutely delicious good decant develop additional bottle complexity next year',
#  'absolutely delicious grape come seghesio good vineyard alexander dry creek',
#  'absolutely delicious impressive tannin acid structure hit no wrong note',
#  'absolutely delicious joy drink taste like fine blackberry preserve spread',
#  'absolutely delicious maybe little one dimensional show petit verdot need',
#  'absolutely delicious offer flood ripe sweet blackberry blueberry currant chocolate',
#  'absolutely delicious offer heady wave orange marmalade butterscotch candy creme',
#  'absolutely delicious offer range blackberry black currant cedar flavor complexe',
#  'absolutely delicious pack sweet blackberry blueberry fruit hint dark chocolate',
#  'absolutely delicious pinot noir hard exaggerate drinkability factor supremely ripe',
#  'absolutely delicious raspberry cherry mocha flavor go great central coast',
#  'absolutely delicious red cherry blueberry jam cherry liqueur cola sandalwood',
#  'absolutely delicious reward year cellar flavor massive suggest rich black',
#  'absolutely delicious right chute no breathing need get plump sweetly',
#  'absolutely delicious right pale color even little brown edge yet',
#  'absolutely delicious show range softly approachable flavor include blackberry cherry',
#  'absolutely delicious silky seductive mouthfeel although least expensive williams selyem',
#  'absolutely delicious source vineyard plant age new french oak intense',
#  'absolutely delicious standard yet dry structure maintain elegant balance drink',
#  'absolutely delicious stuff blackberry black currant bacon flavor not help',
#  'absolutely delicious tannin acid structure firm enable wine age develop',
#  'absolutely delicious wine enjoy wide variety spicy meat cheese vegetarian',
#  'absolutely delicious wine like fine pinot noir silky texture yet',
#  'absolutely delicious yet wine possess structure not easy thing achieve',
#  'absolutely demand age obvious terroir grape come need appellation alexander',
#  'absolutely demand cellaring tannic structure enormous provide sandpapery dryness palate',
#  'absolutely divine blend white grape deliver delicious aroma yellow flower',
#  'absolutely dry almost rasp wine may one rare california chards',
#  'absolutely dry although offer sunburst ripe apple meyer lemon spice',
#  'absolutely dry beautiful tannin acid balance launch classic territory superlative',
#  'absolutely dry body lithe slender show great freshness intensity apple',
#  'absolutely dry boost mouthwateringly zesty acidity also low alcohol one',
#  'absolutely dry brace acidity extraordinarily long deep flavor grape achieve',
#  'absolutely dry bright cherry pie spice flavor show real promise',
#  'absolutely dry brilliantly crisp clean vibrant bubbly rich subtle raspberry',
#  'absolutely dry burst blackberry plum dark chocolate spicy peppery flavor',
#  'absolutely dry crisp acid cherry berry currant flavor perfectly integrate',
#  'absolutely dry crisp acidity not high alcohol make balanced food',
#  'absolutely dry crisp minerally palate stimulate citrus flavor extraordinarily refined',
#  'absolutely dry despite perhaps high alcohol wine unapologetic ripeness instead',
#  'absolutely dry despite size achieve balance harmony one good petite',
#  'absolutely dry develop earthy dry fruit note next six year',
#  'absolutely dry elegantly crisp minerally fruity define elegance flavor veer',
#  'absolutely dry fascinatingly complex high acidity frame citrus fruit green',
#  'absolutely dry finish one good riesling value available cailfornia tremendous',
#  'absolutely dry firm spine tannin structure near perfect divine expression',
#  'absolutely dry flavor rich concentrated suggest summer ripe blackberry mash',
#  'absolutely dry full bodied red coffee cherryskin dry herb flavor',
#  'absolutely dry hard tannin brisk acid berry fruit undertow dry',
#  'absolutely dry high acidity overwhelming complexity milestone drink could go',
#  'absolutely dry high acidity streamline offer tantalize citrus rind peach',
#  'absolutely dry intense acidity subtle earth tobacco herb citrus flavor',
#  'absolutely dry let palate really appreciate acid brightened flavor exotic',
#  'absolutely dry light footed package full rich flavor without attendant',
#  'absolutely dry minerally almost food group strong enough drink appetizer',
#  'absolutely dry quite firm dusty tannin complex array berry herb',
#  'absolutely dry rich tannic structure complex cherry berry tobacco cedar',
#  'absolutely dry show crisp mineralityf pear pineapple toasted meringue sweet',
#  'absolutely dry smooth dense finely ground tannin lend grip structure',
#  'absolutely dry soft cherry tobacco currant flavor swirl together clean',
#  'absolutely dry sturdily tannic tannin ripe sweet frame pure complex',
#  'absolutely dry substantial tannin although soft acidity flavor ripe rich',
#  'absolutely dry superbly racy acidity one high see year balance',
#  'absolutely dry syrahacidic tannic not show much richness bear black',
#  'absolutely dry tannic black currant raisin flavor almost porty not',
#  'absolutely dry tannic smooth complex black currant flavor bright streak',
#  'absolutely dry tannin pronounce easily negotiate good could use fruity',
#  'absolutely dry tannin strong spring mountain way fruit terrifically concentrated',
#  'absolutely dry taste like apricot pineapple tart seasoning nutmeg cinnamon',
#  'absolutely dry tingly acidity citrus flavor wine clean zesty fine',
#  'absolutely easy drink soft silky wine pleasantly ripe berry cherry',
#  'absolutely first class one good petite sirah vintage not surprising',
#  'absolutely first rate bubbly dry smooth rich complex flavor peach',
#  'absolutely first rate cabernet not show big tannin ageworthiness howell',
#  'absolutely first rate dry red wine great substance authority show',
#  'absolutely first rate good anything napa valley produce compellingly addictively',
#  'absolutely first rate wine dry silky savory show crisp acidity',
#  'absolutely good dessert wine ever taste feudo disisa late harvest',
#  'absolutely gorgeous brunello incredibly smooth rich beautiful aroma mature blackberry',
#  'absolutely gorgeous immaculate elegance criticism offer structure bit obvious ageability',
#  'absolutely huge fruit blow bottle soon open rush gorgeous black',
#  'absolutely immaculate aroma succulent cherry violet balsamic note earth root',
#  'absolutely impenetrable almost much good thing black fruit aroma back',
#  'absolutely irresistible fullness harmony intensity aroma long fruity persistency finish',
#  'absolutely irresistible nose generous full sweet succulent definitely please year',
#  'absolutely limit pleasure worth cellare deep core black cherry cassis',
#  'absolutely loaded citrus stone fruit flavor offer support acidity good',
#  'absolutely love high alcohol almost port like although finish absolutely',
#  'absolutely love wine barbaresco santo stefano offer intensity harmony impart',
#  'absolutely lovely aroma beeswax honeysuckle lead lime citrus palate long',
#  'absolutely lovely oak treatment half new not intrusive young tight',
#  'absolutely lovely pinot good gaineys long career dry smooth silky',
#  'absolutely lovely sauvignon blanc fruit fine range lemon lime ripe',
#  'absolutely lovely throw complex cherry rhubarb cola oak aroma turn',
#  'absolutely make grape flavor note keep comingcure ham black truffle',
#  'absolutely mature show almond secondary flavor green herb yeast toast',
#  'absolutely must decant open well black fruit toasted grain firm',
#  'absolutely no sense heaviness excessive weight tannin appear creamy midpalate',
#  'absolutely no show zin traditional hamminess either instead mouth water',
#  'absolutely no well value california zinfandel boxed wine equivalent four',
#  'absolutely not go wrong wine like expression pinot bianco weissburgunder',
#  'absolutely not go wrong wine like plump textured expression rosso',
#  'absolutely not go wrong wine like valpolicella torre dorti easy',
#  'absolutely nothing shy pack real punch way spicy finish good',
#  'absolutely nothing wrong lighter style version cabernet sauvingon syrah merlot',
#  'absolutely opaqueit definitely one dark inkiest wine black currant nose',
#  'absolutely packed ripe blackberry flavor imagine clean finish lovely slowly',
#  'absolutely pure streak lemon stone taut uncompromising speak authentically stone',
#  'absolutely ready drink approachable warm raisiny fruit flavor soft chocolaty',
#  'absolutely refreshingly dry rich note cherry currant tangerine zest finish',
#  'absolutely require bottle age dry leesy mineral compactness show rich',
#  'absolutely spot layer textural detail amplify concentrated core lemon drop',
#  'absolutely stony serious texture full display purity astonishing something authentic',
#  'absolutely stunning testament vintage terroir winemaker impeccable hand delicious beyond',
#  'absolutely stunning wine thick dense array candy fruit caramel marmalade',
#  'absolutely superb pinot noir sumptuously delicious yet capable mid term',
#  'absolutely tart lemon freshness stone earth cling constantly flavor draw',
#  'absolutely terrific informal sparkling rise southern italy make negroamaro grape',
#  'absolutely unique pinot noir tight minerally tannic endlessly fascinating stuff',
#  'absolutely unruly untamed red wine umbria dark impenetrable concentration inky',
#  'absolutely wonderful pinot noir drink fully dry crisp coastal acidity',
#  'absolutely worth search not single vineyard wine blend various block',
#  'absorb acid taste like schisty licorice black fruit spice choppy',
#  'absorb bake cherry plum flavor touch rustic stalky roasted aftertaste',
#  'absorb beautiful toasted quality associate oak age sophisticated smooth peach',
#  'absorb flavor herbal red plum choppy turn gritty fiery finish',
#  'absorb fruit wood age act support rich texture develop well',
#  'absorb heat contrast strawberry preserve moist earth raspberry roll nutty',
#  'absorb heat not exaggerated way expression open ripe fruit note',
#  'absorb intensely sweet wine final citrusy edge add fine contrast',
#  'absorb lavish coat new oak flavor candy pineapple tart meyer',
#  'absorb leave herbal black fruit fig peppery flavor warm toasty',
#  'absorb natural color grey pinkish grape variety fresh wine redolent',
#  'absorb new french oak without wood stick criticism big one',
#  'absorb taste like mix plum blackberry chocolate finish darken note',
#  'absorb texture wine like many roederer vintage release age give',
#  'absorb time always excessive young wine pleasant cherry black raspberry',
#  'absorb wine acidity flavor celery bell pepper lime tangerine come',
#  'absorb wine broad foundation flavor smoke oak plum wild berry',
#  'absorb wine fabric front salty note back briny apple nectarine',
#  'absorbingly complex racy textural mineral drive flavor excellent wine feature',
#  'abstberg auslese regular auslese almost delicate comparison feature slatey minerally',
#  'abstberg crushed stone spice melon scent flesh embellish palate honeyed',
#  'absurd good tempranillo full clean deep aroma black fruit licorice',
#  'absurdly price carmenere always one chile well vintage fine cherry',
#  'abtsberg superior inferior herrenberg counterpart remain good wine hint sweat',
#  'abundance along clean green good way berry banana pineapple fruit',
#  'abundance along kiwi sour apple tad disjointed taste big full',
#  'abundance american oak wine medium bodied creamy oaky palate slightly',
#  'abundance apple flavorsgreen golden red cheekedplay nose crisp crunchy sweet',
#  'abundance back moderate acid wine side flabby drink enjoy youthful',
#  'abundance baked apple pear dance around light remembrance lemon souffle',
#  'abundance barrel flavor baking spice overpower signature element distinguished vineyard',
#  'abundance black cherry raspberry cinnamon approachable full bodied tannin soft',
#  'abundance black fruit along leather dry herb note palate although',
#  'abundance black pepper earth black cherry flavor cool crisp style',
#  'abundance bright berry fruit wine lean compact mouth fresh close',
#  'abundance caramel oak supporting role try one drink rather save',
#  'abundance complex mix tree fruit stone fruit streak earth fine',
#  'abundance crisp red plum flavor pretty floral tone finish drink',
#  'abundance dark roasted espresso flavor moment chalky tannin threaten outrun',
#  'abundance delicious acidity give lift classic barbecue wine great summer',
#  'abundance dry tannin power solid dense structure also bright fruit',
#  'abundance edge smooth balance perfect fruit pure expressive wine resonate',
#  'abundance everything mark good barrel selection always winery expensive chardonnay',
#  'abundance fine grain tannin velvety texture tasty linger finish good',
#  'abundance forward jammy blackberry cherry fruit hand tannin considerable acidity',
#  'abundance fresh apple citrus note nose palate unoaked wine rich',
#  'abundance fresh apple floral note long toasted nut skin finish',
#  'abundance fresh grapy flavor soft supportive texture aroma pretty strong',
#  'abundance fresh pear lemon flavor subtly oake hint vanilla cream',
#  'abundance fresh squeezed citrus minerality remain light complex palate teeter',
#  'abundance fruit along density texture rarely find domestic chardonnay fruit',
#  'abundance fruit flavor note white pear apricot portray ripe warm',
#  'abundance fruit not conceal absolute purity concentration core dry structured',
#  'abundance fruity supple hint leather well build without tannic show',
#  'abundance get depth vitality youthful verve promise fine ageability age',
#  'abundance green pepper leafy flavor throughout soft tannin acidity not',
# ...
#  'abundant vanilla nutmeg flavor make wine easy like nicely dry',
#  'abundant vanilla sweet spice tone nose palate pleasurable grippy tannin',
#  'abundant vanilla toasted oak note hint fresh herb peppery black',
#  'abundant white peach berry flavor belhurst rise sweet side dry',
#  'abundant yellow fruit kiwi soft mineral mouth yield generous bright',
#  'abundant yellow peach tangerine flavor lemonade like acidity brisk refreshing',
#  'abundant yet surprisingly integrate nose palate monticello cab franc amidst',
#  'abundantly fleshy melon grapefruit note red newt circle riesling semidry',
#  'abundantly floral fruity load lavender peony sweet grapefruit note dry',
#  'abundantly floral fruity penetrate acidity maintain balance structure finish dry',
#  'abundantly floral honey nose deeply concentrated palate layer luscious fig',
#  'abundantly fragrant note sweet cherry blossom freshly cut herb palate',
#  'abundantly lavish well define aroma black cherry root beer sizzling',
#  'abundantly proportion wine full bodied opulent texture enough fine grain',
#  'abundantly ripe mango pineapple nose palate semidry riesling irresistibly lush',
#  'abundantly ripe peach melon flavor semidry riesling juicy sweet without',
#  'abupt finish similar minor chardonnay buttercream vanilla tropical citrus fruit',
#  'abuse really mean something winerys top cuveean excellent effort spend',
#  'abut fruit citrus crisp green apple dominate end convey bright',
#  'abv additional scent olive savory plum feed tight palate live',
#  'abv aroma surprisingly delicate offer strawberry raspberry fruit compote full',
#  'abv burst roasted coffee licorice dry tannin around soft supple',
#  'abv cabernet taste like still residual sweetness rich ripe blackberry',
#  'abv fairly weighty wine palate dry silky texture hint mossy',
#  'abv full bodied rich velvety example mclaren vale shiraz winemaker',
#  'abv give heat combine pepper flavor lend prickliness flavor overripe',
#  'abv give sweet blackberry blueberry chocolate flavor heat lack complexity',
#  'abv heat accompany raisin cassis sweet oak flavor not conform',
#  'abv hot chili pepper wine handle slender flavor not handle',
#  'abv light palate dance vibrant grass citrus flavor crisp acid',
#  'abv may not sweet expect still show razor like focus',
#  'abv monster finger lake standard unsurprising perhaps hot vintage tad',
#  'abv not exactly ring freshness agility score point full bodied',
#  'abv not shy wine neither richly textured may expect drink',
#  'abv slightly sweet yet show taut wiry frame crisp green',
#  'abv smell pastry earth soft berry fruit feel round reticent',
#  'abv steve webber de bortoli man medium bodied chardonnay display',
#  'abv still retain residual sugar fruit clearly ripe ripeness reflect',
#  'abv sweet black cherry jam raisin chocolatey finish not everyone',
#  'abv tannin supple fruit plummy savory spicy make good buy',
#  'abv well without ever feel hot awkward instead fine acidity',
#  'abv wine concentrate almost black color classic malbec solid tannin',
#  'abv yet beautiful example mclaren vale shiraz ample toast vanilla',
#  'abyss black adhere unwritten well understand rule armagh must big',
#  'abyss deep black aroma steak pepper licorice palate not knock',
#  'ac harvest late ridiculously low yield barrel ferment age result',
#  'acacia also deliver fruit tone peach pear touch almond marzipan',
#  'acacia aroma lift glass bright palate offer ripe pear nectarine',
#  'acacia back subtle hint dry sage basil luminous soave aromatic',
#  'acacia back sweet almond peach show light bubble fade fast',
#  'acacia barrel deeply color white aroma candy citrus mature apple',
#  'acacia barrel help round fruity flavor without sacrifice focus precision',
#  'acacia barrel intense grassy deep splash citrus long tangy finish',
#  'acacia barrel well tank result mix floral fruity melon firm',
#  'acacia beeswax carry palate candied lemon apple concentrated rather one',
#  'acacia beeswax citrus stone fruit linear palate deliver pink grapefruit',
#  'acacia blossom aroma follow plump largely anonymous palate turn apricot',
#  'acacia blossom aroma structured tight palate ripe earthy fruit anise',
#  'acacia blossom center stage nose palate deal nut skin lime',
#  'acacia blossom clover honey buttercup lead note cassis bone dry',
#  'acacia blossom great warm weather aperitif wine well one go',
#  'acacia blossom jasmine freshly peel tangerine skin rich foamy mouthfeel',
#  'acacia blossom lime give way sturdy pear flavor lemony finish',
#  'acacia blossom luscious aroma toasted nut citrus honey nut mineral',
#  'acacia blossom patchouli oil give interesting true cafayate bouquet palate',
#  'acacia blossom play ripe pear note nose palate offer pleasant',
#  'acacia blossom red berry cola brown sugar wrap supple tannin',
#  'acacia blossom texture lush flavor bold fade bit intensity finish',
#  'acacia cask wine show tertiary flavor palate include smoky mineral',
#  'acacia crisp minerally mark stone fruit well citrus finish rich',
#  'acacia earthy note spry nine year old mature waxy palate',
#  'acacia exotic fruit follow clean crisp easygoing mouthfeel pretty floral',
#  'acacia exotic fruit would go easily casual setting holiday creamy',
#  'acacia flavor profile include ripe apple melon bit citrus finish',
#  'acacia flower aroma carry tangy linear palate along pineapple citrus',
#  'acacia flower aroma meld together elegant white firm palate offer',
#  'acacia flower background wine full generous sweet peachy flavor creamy',
#  'acacia flower bake apple barbecue spice mouth get pure lavender',
#  'acacia flower beeswax white stone fruit succulent palate offer creamy',
#  'acacia flower chamomile stone fruit whiff dry hay savory palate',
#  'acacia flower chop kiwi wine taste creamy slightly sweet chewy',
#  'acacia flower citrus spring flower note add attractive dimension wine',
#  'acacia flower dry papaya stone fruit pithy minerality scent flavor',
#  'acacia flower even touch honey flow glass smooth seamless coat',
#  'acacia flower hint almond nut bubbling steady direct leave soda',
#  'acacia flower hint vanilla honey creamy palate offer bartlett pear',
#  'acacia flower honey crush white pepper wine steady smooth palate',
#  'acacia flower honey distant note ripe melon back light fresh',
#  'acacia flower honey flavor winemaker suggest pair blue cheese sweetness',
#  'acacia flower honey kiwi grapefruit honey appear nose follow flavor',
#  'acacia flower honey luscious ripeness give wine broad heavy feel',
#  'acacia flower honey round evolve palate still boast freshness tertiary',
#  'acacia flower honey softly bubbly wine show sweetness follow crisp',
#  'acacia flower honey stone fruit lack sweetness hold back aromatic',
#  'acacia flower honey waft smoke drift glass tangy medium bodied',
#  'acacia flower honeysuckle hint buttered toffee rich full bodied without',
#  'acacia flower honeysuckle wine creamy rich soft pretty tangerine mousse',
#  'acacia flower jasmine sweet tangy mouth right measure would pair',
#  'acacia flower lightly lace green fruit flower everything pinot grigio',
#  'acacia flower lightly toast oak smooth structured palate offer lemon',
#  'acacia flower make extremely aromatic wine burst sweet fruit freshness',
#  'acacia flower melon peach blossom honey golden delicious apple creamy',
#  'acacia flower moist earth aromatic herb scent mingle fresh orchard',
#  'acacia flower orange zest peach thank small percentage verdiso perera',
#  'acacia flower orchard fruit come together glass firm palate offer',
#  'acacia flower orchard fruit palate oak drive sensation compete yellow',
#  'acacia flower palate deliver apple citrus flavor along note bread',
#  'acacia flower peach blossom apricot palate deliver citrus walnut bread',
#  'acacia flower peach yellow candy hard imagine pair could either',
#  'acacia flower ripe stone fruit dry sage palate not overly',
#  'acacia flower smoke palate offer apricot tropical fruit bread crust',
#  'acacia flower spanish broom beeswax flint tree fruit delicious palate',
#  'acacia flower spice crisp refreshing palate deliver white peach white',
#  'acacia flower stone fruit apricot mature melon also touch roasted',
#  'acacia flower stone fruit cap subtle note white mineral wine',
#  'acacia flower stone fruit wine fresh clean touch bitter almond',
#  'acacia flower straightforward palate offer yellow apple nectarine chopped herb',
#  'acacia flower sweet sparkler present mouthful creamy foam bright bubble',
#  'acacia flower whiff mediterranean herb bright palate offer lemon zest',
#  'acacia flower white flower beeswax creamy palate deliver apple nut',
#  'acacia flower wine creamy soft mouth playfully sour note citrus',
#  'acacia flower yellow fruit butterscotch honeyload honey mouth lean fresh',
#  'acacia french oak barrel show note lemon smoke slightly burn',
#  'acacia green melon aroma flavor wine plump refreshing honest cafayate',
#  'acacia hint lemon zest silky frothy palate deliver white peach',
#  'acacia honey candy lemon peel lovely bright still totally fresh',
#  'acacia honey confectionary note coffee flavor close finish bright acidity',
#  'acacia honey ripe annurca apple hazelnut aroma carry vanilla inflect',
#  'acacia honey soapy moscato like quality aromatic white floral fragrance',
#  'acacia honey white peach citrus nicely taut focus palate minerally',
#  'acacia honey white peach light fresh would perfect serve hot',
#  'acacia honeysuckle flesh peach melon not acidic mouth import fair',
#  'acacia honeysuckle note since barrel fermented not thick wine instead',
#  'acacia honeysuckle peach load yellow fruit clean polish lean mouthfeel',
#  'acacia honeysuckle peach sweet intensity hold line pretty mineral endnote',
#  'acacia interesting note livio felluga among first producer call grape',
#  'acacia jasmine honeysuckle play leading role support cast stone fruit',
#  'acacia juicy medium bodied palate offer ripe pear lemon peel',
#  'acacia lemon drop smoky mineral savory palate deliver lemon zest',
#  'acacia lilac accent rich toasty nose no hold bar wine',
#  'acacia linear palate deliver mature pear yellow apple accent bitter',
#  'acacia lively palate offer ripe yellow apple candy citrus walnut',
#  'acacia lively palate offer white peach green apple pineapple alongside',
#  'acacia lychee aroma none cheap perfume sometimes ruin variety palate',
#  'acacia melon press flower pair fruit base dessert peach pudding',
#  'acacia nose luminous white award note wild flower kiwi cut',
#  'acacia nose mouth however bit austere sharp edged deliver steely',
#  'acacia nut aroma lead nose follow straightforward enjoyable palate along',
#  'acacia oak deep rich flavor pack sliced pear range orange',
#  'acacia oak lead nose vibrant palate offer yellow apple citrus',
#  'acacia orange blossom beeswax creamy palate deliver intense honey flavor',
#  'acacia orange blossom nose palate full bore citrus deal orange',
#  'acacia orange blossom palate deliver pineapple pear white cherry flavor',
#  'acacia orange blossom palate offer white peach apricot flavor along',
#  'acacia orange blossom show modest weight acidity citrus tropical fruit',
#  'acacia orange candy even bit pineapple combine fruity delicious wine',
#  'acacia palate dry full green apple nut remain dry seltzer',
#  'acacia palate pump melon apple flavor big precise not rewarding',
#  'acacia palate show white peach citrus toasted almond flavor creamy',
#  'acacia peach exotic fruit none element intense wine appear simple',
#  'acacia perfume pretty spry wine tart green apple pear flavor',
#  'acacia polished stone pink grapefruit peach obvious component opulent aromatic',
#  'acacia ride heel peach nectarine simple white wine good freshness',
#  'acacia rise petal citrus blossom move luscious midpalate load apple',
#  'acacia soft foaming feel lush creamy mouth sweet honey flavor',
#  'acacia spanish broom chamomile palate dole white peach tangerine zest',
#  'acacia spanish broom citrus aroma lead nose wine envelop structure',
#  'acacia spanish broom flint creamy peach citrus honeydew carry palate',
#  'acacia stay light crystallize palate fresh cantaloupe mango flavor good',
#  'acacia stone fruit fragrant honey note particularly opulent refined mouth',
#  'acacia talc flavor solid persistent palate yield green melon honey',
#  'acacia toast oak aroma follow palate yellow apple citrus drop',
#  'acacia toasted bread fresh palate deliver peach apricot kiwi note',
#  'acacia tropical fruit palate simple deliver solid flavor lychee melon',
#  'acacia vanilla grassy citrus apple aroma nose energetic palate come',
#  'acacia vanilla toast rich palate show complexity deliver bread crust',
#  'acacia walnut linear palate offer bartlett pear lemon zest golden',
#  'acacia whiff beeswax austere palate offer green pear citrus mineral',
#  'acacia whiff beeswax juicy palate offer grapefruit exotic fruit pineapple',
#  'acacia white peach pear elegant wine skip lightly across palate',
#  'acacia white spring flower accent hint stone fruit palate offer',
#  'acacia wild flower feel round oily green melon vanilla peach',
#  'acacia wine golden color amber highlight mouthfeel less dense structured',
#  'acacia wood barrel beautifully ripe wine full bodied pack apricot',
#  'acacia wood barrel give less wood flavor oak attractive lightly',
#  'acacia wood cask nut spice lychee honey black pepper element',
#  'acacia wood concrete show clean gala apple brioche aroma grippy',
#  'acacia wood structure wine open aroma alpine wild flower herb',
#  'acaciaalongside white peach nectarine strong mineral focus nose sweet yet',
#  'academic interest consumer lucky enough latch onto bottle two try',
#  'acccessible syrah tannic acidic properly appreciate although decanting help unleash',
#  'accelerate tight rein notion gun flint vague leafiness pinwheel pink',
#  'accelerator much force not ideally balanced import global vineyard importer',
#  'accent acidity juicy fragrant fill crispness almost new world fruit',
#  'accent add character bouquet wine otherwise dominate black cherry plum',
#  'accent add character red berry white strawberry aroma flavor wine',
#  'accent add character smooth silky mouth medium finish land softly',
#  'accent add complexity bright acidity mark lean angular wine make',
#  'accent add complexity broaden nutmeg spice full bodied balanced deliver',
#  'accent add complexity mouthfeel velvety soft finish touch warmth probably',
#  'accent add complexity spiced fruitcake cocoa roasted nut huge flavor',
#  'accent add depth medium tannin provide solid structure carry medium',
#  'accent add depth nose well integrate oak flavor infuse palate',
#  'accent add depth palate medium acidity help lift medium length',
#  'accent add enough interest prevent descent sticky simplicity package turn',
#  'accent add flavor sour plum graceful palate texture suave luxurious',
#  'accent add interest overall feel bright yet full close mineral',
#  'accent add interest palate slight creaminess midpalate lift ample acidity',
#  'accent add interest palate taste wax spiced toast although wine',
#  'accent age new oak detail iron baking spice emerge also',
#  'accent aggressive astringent wood tannin combine lack evident freshness palate',
#  'accent aid nose full bodied godello offer polished apple peach',
#  'accent almond recur blueberry creamy textured finish long supple tannin',
#  'accent almond vanilla increase complexity sip one californias blue chip',
#  'accent alongside dry wood tannin racy acidity no fruit richness',
#  'accent already show solid component knit together well little time',
#  'accent also faint mustiness mouth mild lime melon flavor display',
#  'accent also less enjoyable sharp tart note really take show',
#  'accent also show whiff acetone bother taster wine comfortable ground',
#  'accent also slight meatiness overall impression thin many southern french',
#  'accent also soft tone coffee leather juicy black cherry overall',
#  'accent also sour streak sulfurous note refuse yield wine finish',
#  'accent also substantial dose iodine earth vitamin character south african',
#  'accent also vie attention tightly wind burn toast mineral finish',
#  ...]
